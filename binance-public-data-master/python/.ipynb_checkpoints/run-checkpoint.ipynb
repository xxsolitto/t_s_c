# %%
# %run download-trade.py
# Out:
# fetching all symbols from exchange
# Found 1501 symbols
# [1/1501] - start download monthly ETHBTC trades
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-01.zip
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-02.zip
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-03.zip
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-04.zip
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-05.zip
#
# File not found: https://data.binance.vision/data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-06.zip
#
# File Download: C:\Users\zxxxs\study\binance-public-data-master\python\data/spot/monthly/trades/ETHBTC/ETHBTC-trades-2017-07.zip
# [##################################################]
# ...
