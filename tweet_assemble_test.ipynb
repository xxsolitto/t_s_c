# %%
# !pip install tweepy
import tweepy

# 認証に必要なキーとトークン
API_KEY = '9FhHuubkRHSis8hVDnv6HYcvI'
API_SECRET = 'HGcNWRMjv1HUXW1gDEkjLfcmXdieBh9H5NvX72iGpsPozNhWxc'
ACCESS_TOKEN = '1391014464099520516-KiUwHzZ2XoLnAGzYdYxAc88bPB2JFc'
ACCESS_TOKEN_SECRET = 'yQoI8nyEEM1nEpPWyIbZ4Nj8naPI4PVya3MbcOE0zUPPA'

# APIの認証
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# キーワードからツイートを取得
api = tweepy.API(auth)
tweets = api.search(q=['$ETH'], count=100)

for tweet in tweets:
    print('-----------------')
    print(tweet.text)
# Out:
# -----------------
# RT @WickedCraniums: ::::: WATCH OUT FOR THIS GIVEAWAY :::::
#
# 10,762 Craniums launching soon, each priced at 0.06 ETH.
#
# To win this Wicked…
# -----------------
# RT @ShaunWitriol: Here are the numbers on EVERYTHING related to #SAFEMOON from @reporternaut
#
# Today we wait on #SAFEMOONWALLET 📈signups and…
# -----------------
# RT @CayIlker: Last call to Moon. #smoon ship is ready to takeoff @saylormoonarmy is growing fast! Take your seat and enjoy the moon 🚀🚀🚀 #bt…
# -----------------
# RT @Power09634017: @myteamchain This my entry for partisipan meme contest
#
# @myteamchain
# #Myteamcoin
# #meme
# #btc #eth #bnb #bsc
# #crypto…
# -----------------
# RT @PikaCrypto_: ⚡️THUNDER STAKING IS LIVE⚡️
#
# -Head over to: https://t.co/XYFRdkWROf
#
# -Select Thunder Staking, make sure you read the main…
# -----------------
# #GoldmanSachs revealed its plan to expand its #crypto trading desk🧐
#
# #ethereum #ether $ETH
#
# ▶️READ MORE:
# https://t.co/RHBOHSALou
# ...
